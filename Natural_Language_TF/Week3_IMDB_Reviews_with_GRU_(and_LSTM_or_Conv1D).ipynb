# %%
import tensorflow as tf
print(tf.__version__)

import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", 
                       with_info=True, 
                       as_supervised=True)
# Out:
# 2.3.0
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBGZ7S7/imdb_reviews-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBGZ7S7/imdb_reviews-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBGZ7S7/imdb_reviews-unsupervised.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np
train_data, test_data = imdb['train'],imdb['test']

training_sentences = []
training_labels = []
testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
  return ' '.join([reverse_word_index.get(i,'?') for i in text])
print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %% [markdown]
# # GRU

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, 
                              input_length=max_length), #embedding_dim = 16
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 10
history = model.fit(padded, training_labels_final, 
                    epochs=num_epochs, 
                    validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                9600
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 62s 79ms/step - loss: 0.5149 - accuracy: 0.7178 - val_loss: 0.3789 - val_accuracy: 0.8387
# Epoch 2/10
# 782/782 [==============================] - 61s 79ms/step - loss: 0.3084 - accuracy: 0.8728 - val_loss: 0.3994 - val_accuracy: 0.8278
# Epoch 3/10
# 782/782 [==============================] - 61s 78ms/step - loss: 0.2351 - accuracy: 0.9096 - val_loss: 0.4390 - val_accuracy: 0.8164
# Epoch 4/10
# 782/782 [==============================] - 62s 79ms/step - loss: 0.1812 - accuracy: 0.9321 - val_loss: 0.4977 - val_accuracy: 0.8110
# Epoch 5/10
# 782/782 [==============================] - 62s 80ms/step - loss: 0.1322 - accuracy: 0.9534 - val_loss: 0.5183 - val_accuracy: 0.8162
# Epoch 6/10
# 782/782 [==============================] - 63s 80ms/step - loss: 0.0929 - accuracy: 0.9685 - val_loss: 0.5770 - val_accuracy: 0.8164
# Epoch 7/10
# 782/782 [==============================] - 62s 80ms/step - loss: 0.0653 - accuracy: 0.9782 - val_loss: 0.6541 - val_accuracy: 0.8042
# Epoch 8/10
# 782/782 [==============================] - 62s 79ms/step - loss: 0.0433 - accuracy: 0.9857 - val_loss: 0.7517 - val_accuracy: 0.8111
# Epoch 9/10
# 782/782 [==============================] - 63s 80ms/step - loss: 0.0311 - accuracy: 0.9897 - val_loss: 0.7917 - val_accuracy: 0.8172
# Epoch 10/10
# 782/782 [==============================] - 63s 81ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.9084 - val_accuracy: 0.8063

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# # LSTM

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length), #embedding_dim = 16
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

history = model.fit(padded, training_labels_final, 
                    epochs=num_epochs, 
                    validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 64)                12544
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 172,941
# Trainable params: 172,941
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 61s 78ms/step - loss: 0.6413 - accuracy: 0.6300 - val_loss: 0.4845 - val_accuracy: 0.7827
# Epoch 2/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.3991 - accuracy: 0.8333 - val_loss: 0.4353 - val_accuracy: 0.8308
# Epoch 3/10
# 782/782 [==============================] - 59s 76ms/step - loss: 0.3717 - accuracy: 0.8603 - val_loss: 0.5970 - val_accuracy: 0.6746
# Epoch 4/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.3805 - accuracy: 0.8465 - val_loss: 0.4019 - val_accuracy: 0.8319
# Epoch 5/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.2501 - accuracy: 0.9069 - val_loss: 0.4161 - val_accuracy: 0.8271
# Epoch 6/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.2030 - accuracy: 0.9304 - val_loss: 0.4103 - val_accuracy: 0.8356
# Epoch 7/10
# 782/782 [==============================] - 61s 78ms/step - loss: 0.1723 - accuracy: 0.9430 - val_loss: 0.4686 - val_accuracy: 0.8286
# Epoch 8/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.1493 - accuracy: 0.9522 - val_loss: 0.5058 - val_accuracy: 0.8272
# Epoch 9/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.1253 - accuracy: 0.9622 - val_loss: 0.5620 - val_accuracy: 0.8244
# Epoch 10/10
# 782/782 [==============================] - 60s 77ms/step - loss: 0.1110 - accuracy: 0.9676 - val_loss: 0.5538 - val_accuracy: 0.8224

# %%
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# Highest validation accuracy 85%

# %% [markdown]
# # Conv1D

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length), #embedding_dim = 16
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

history = model.fit(padded, training_labels_final, 
                    epochs=num_epochs, 
                    validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,149
# Trainable params: 171,149
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.4378 - accuracy: 0.7908 - val_loss: 0.3476 - val_accuracy: 0.8477
# Epoch 2/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.2806 - accuracy: 0.8844 - val_loss: 0.3571 - val_accuracy: 0.8443
# Epoch 3/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.2291 - accuracy: 0.9103 - val_loss: 0.4062 - val_accuracy: 0.8282
# Epoch 4/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.1922 - accuracy: 0.9272 - val_loss: 0.4226 - val_accuracy: 0.8330
# Epoch 5/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.1603 - accuracy: 0.9434 - val_loss: 0.4768 - val_accuracy: 0.8246
# Epoch 6/10
# 782/782 [==============================] - 11s 15ms/step - loss: 0.1306 - accuracy: 0.9577 - val_loss: 0.5198 - val_accuracy: 0.8204
# Epoch 7/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.1070 - accuracy: 0.9659 - val_loss: 0.5746 - val_accuracy: 0.8174
# Epoch 8/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.0835 - accuracy: 0.9748 - val_loss: 0.6849 - val_accuracy: 0.8127
# Epoch 9/10
# 782/782 [==============================] - 12s 16ms/step - loss: 0.0659 - accuracy: 0.9819 - val_loss: 0.7892 - val_accuracy: 0.8081
# Epoch 10/10
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0564 - accuracy: 0.9832 - val_loss: 0.9124 - val_accuracy: 0.8020

# %%
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
